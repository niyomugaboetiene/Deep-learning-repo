# %%
# We are going to install tensorflow

# %%
import tensorflow # in throws an error means it is not yet installed
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.9/572.9 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:09
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 4.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 5.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 3.7 MB/s eta 0:00:004.4 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 2.2 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [tensorflow]37m━━ 16/17 [tensorflow]]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785681056.004278    6988 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1785681056.150105    6988 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785681060.216681    6988 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
# %matplotlib inline

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data() # this is how we load datasets in tensoflow
# mnist is handrwitten dataset with huge collection of numbers
# there are also Fashion mnist
# CIFAR-10 for cars, cats, airplanes, ...

# %%
# We need to scale the data for better training
X_train = X_train / 255
X_test = X_test / 255

# %%
len(X_train)
# Out:
# 60000

# %%
len(X_test)
# Out:
# 10000

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train[0]
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
plt.matshow(X_train[0])

# %%
plt.matshow(X_train[4])

# %%
y_train[4]
# Out:
# np.uint8(9)

# %%
y_train[:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
X_train.shape
# We need to convert the 2D Into 1D
(60000, 784)
# Out:
# (60000, 784)

# %%
X_train_flattened = X_train.reshape(len(X_train), 28 * 28)
X_test_flattened = X_test.reshape(len(X_test), 28 * 28)
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
X_test_flattened.shape
# Out:
# (10000, 784)

# %%
print(X_train_flattened.shape)
print(y_train.shape)

print(X_test_flattened.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
X_train_flattened[0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape = (784,), activation='sigmoid')
])
# .Dense means every input layer will connected to each output layer and define the input numbers and the output which is 10
# activation='sigmoid' will convert number into range of 0 and 1

# define how I want my model to train
model.compile( 
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
model.fit(X_train_flattened, y_train, epochs = 9) # it will repeats 9 times
# Out:
# W0000 00:00:1785682296.038155    6988 cpu_allocator_impl.cc:82] Allocation of 188160000 exceeds 10% of free system memory.
# Epoch 1/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7875 - loss: 1.3600
# Epoch 2/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.7987 - loss: 1.2533
# Epoch 3/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8075 - loss: 1.1614
# Epoch 4/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8161 - loss: 1.0821
# Epoch 5/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8217 - loss: 1.0137
# Epoch 6/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8278 - loss: 0.9544
# Epoch 7/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8326 - loss: 0.9028
# Epoch 8/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.8379 - loss: 0.8577
# Epoch 9/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8423 - loss: 0.8181

# %%
# test the model
model.evaluate(X_test_flattened, y_test)
# Out:
# W0000 00:00:1785683134.742049    6988 cpu_allocator_impl.cc:82] Allocation of 31360000 exceeds 10% of free system memory.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8525 - loss: 0.7797
# [0.7796924114227295, 0.8525000214576721]

# %%
plt.imshow(X_test[0])

# %%
predicted = model.predict(X_test_flattened)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
predicted[0]
# Out:
# array([0.16567068, 0.14915843, 0.21226637, 0.35323974, 0.41810742,
#        0.3147721 , 0.09118792, 0.95701826, 0.24100398, 0.66560906],
#       dtype=float32)

# %%
np.argmax(predicted[0])
# Out:
# np.int64(7)

# %%
y_predicted_labels = [np.argmax(i) for i in predicted]

y_predicted_labels[:4]
# Out:
# [np.int64(7), np.int64(2), np.int64(1), np.int64(0)]

# %%
y_test[:4]
# Out:
# array([7, 2, 1, 0], dtype=uint8)

# %%
cm = tf.math.confusion_matrix(labels=y_test, predictions = y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 930,    0,    5,    5,    0,   11,   22,    1,    6,    0],
#        [   0, 1095,    9,    3,    0,    3,    5,    0,   20,    0],
#        [  16,   37,  836,   23,   20,    1,   30,   24,   42,    3],
#        [   4,   21,   30,  869,    1,   20,    8,   19,   26,   12],
#        [   2,   13,    3,    0,  843,    0,   22,    4,    8,   87],
#        [  18,   48,    7,  104,   27,  605,   25,   17,   20,   21],
#        [  16,   25,   13,    0,   17,   18,  868,    0,    1,    0],
#        [   1,   48,   18,    3,   13,    0,    1,  898,    9,   37],
#        [  16,   47,   12,   62,   13,   18,   16,   15,  749,   26],
#        [  16,   19,    6,   11,   62,    7,    0,   47,    9,  832]],
#       dtype=int32)>

# %%
import seaborn as sns

plt.figure(figsize= (10, 7))
sns.heatmap(cm, annot = True, fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape = (784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])
# .Dense means every input layer will connected to each output layer and define the input numbers and the output which is 10
# activation='sigmoid' will convert number into range of 0 and 1

# define how I want my model to train
model.compile( 
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
model.fit(X_train_flattened, y_train, epochs = 9) # it will repeats 9 times
# Out:
# Epoch 1/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9122 - loss: 0.3071
# Epoch 2/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9152 - loss: 0.2952
# Epoch 3/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9180 - loss: 0.2851
# Epoch 4/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9202 - loss: 0.2765
# Epoch 5/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9222 - loss: 0.2686
# Epoch 6/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.9249 - loss: 0.2614
# Epoch 7/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9271 - loss: 0.2539
# Epoch 8/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9291 - loss: 0.2471
# Epoch 9/9
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9309 - loss: 0.2403

# %%
# test the model
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9317 - loss: 0.2365
# [0.23646672070026398, 0.9316999912261963]

# %%
predicted = model.predict(X_test_flattened)
y_predicted_labels = [np.argmax(i) for i in predicted]
cm = tf.math.confusion_matrix(labels=y_test, predictions = y_predicted_labels)

plt.figure(figsize= (10, 7))
sns.heatmap(cm, annot = True, fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Text(95.72222222222221, 0.5, 'Truth')
