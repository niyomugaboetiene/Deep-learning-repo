# %%
import numpy as np
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Embedding
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789884086.343037   13693 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1789884093.390638   13693 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789884102.060381   13693 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 from tensorflow.keras.preprocessing.text import one_hot
# ----> 3 from tensorflow.keras.preprocessing.sequence import pad_sequence
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Dense
#
# ImportError: cannot import name 'pad_sequence' from 'tensorflow.keras.preprocessing.sequence' (/home/etiene-niyomugabo123/miniconda3/lib/python3.13/site-packages/keras/_tf_keras/keras/preprocessing/sequence/__init__.py)
