# %%
import numpy as np

# %%
revenue = np.array([[180, 40, 60], [30, 120, 50], [100, 40, 60]])
expenses = np.array([[80, 90, 100], [30, 60, 20], [10, 65, 70]])

# %%
profitOrLoss = revenue - expenses
profitOrLoss
# Out:
# array([[100, -50, -40],
#        [  0,  60,  30],
#        [ 90, -25, -10]])

# %%
pricePerUnit = np.array([1000, 600, 200])
units = np.array([[30, 40, 60], [5, 10, 15], [2, 5, 7]])
# numpy broadcasting is the way matrix handle the array with different shapes
