# %%
import tensorflow as tlf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785913205.956124   21685 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1785913212.911199   21685 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785913220.706344   21685 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df[['age', 'affordibility']], df.bought_insurance, test_size=0.2, random_state=42
)

# %%
len(X_train)
# Out:
# 22

# %%
X_train_scaled = X_train.copy()
X_train_scaled = X_train_scaled['age'] / 100

X_test_scaled = X_test.copy()
X_test_scaled = X_test_scaled['age'] / 100

# %%
X_train_scaled
# Out:
# 17    0.58
# 22    0.40
# 11    0.28
# 13    0.29
# 15    0.55
# 1     0.25
# 4     0.46
# 5     0.56
# 2     0.47
# 16    0.25
# 23    0.45
# 3     0.52
# 26    0.23
# 24    0.50
# 18    0.19
# 27    0.46
# 20    0.21
# 7     0.60
# 10    0.18
# 14    0.49
# 19    0.18
# 6     0.55
# Name: age, dtype: float64
