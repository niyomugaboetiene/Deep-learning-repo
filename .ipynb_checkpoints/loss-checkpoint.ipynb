# %%
import numpy as np

# %%
y_pred = np.array([1, 1, 0, 0, 1])
y_true = np.array([0.4, 0.2, 0, 0, 0.9])

# %%
def mae(y_true, y_pred):
    total_abs = 0
    for yt, yp in zip(y_true, y_pred):
        total_abs += abs(yt - yp)
    print("Total error", total_abs)
    mae = total_abs / len(y_pred)
    print("MAE", mae)

# %%
mae(y_true, y_pred)
# Out:
# Total error 1.5
# MAE 0.3

# %%
np.sum(np.abs(y_true - y_pred))
# Out:
# np.float64(1.5)

# %%
 eplison = 1e-15

# %%
y_predicted_new = [max(i, eplison) for i in y_pred]
y_predicted_new
# Out:
# [np.int64(1), np.int64(1), 1e-15, 1e-15, np.int64(1)]

# %%
y_predicted_new = [min(i, 1-eplison) for i in y_pred]
y_predicted_new
# Out:
# [0.999999999999999,
#  0.999999999999999,
#  np.int64(0),
#  np.int64(0),
#  0.999999999999999]
