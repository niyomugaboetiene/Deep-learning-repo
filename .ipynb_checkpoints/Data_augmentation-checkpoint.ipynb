# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /home/etiene-niyomugabo123/miniconda3/lib/python3.13/site-packages (12.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL 
import tensorflow as tf
import numpy as np
import os
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786773361.138157   20682 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1786773361.221949   20682 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786773363.715817   20682 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file("flowers_photos", origin=dataset_url, cache_dir=".", untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
#  22126592/228813984 ━━━━━━━━━━━━━━━━━━━━ 1:24 0us/step
