# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /home/etiene-niyomugabo123/miniconda3/lib/python3.13/site-packages (from gensim) (2.3.4)
# Requirement already satisfied: scipy>=1.7.0 in /home/etiene-niyomugabo123/miniconda3/lib/python3.13/site-packages (from gensim) (1.16.3)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-8.0.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in /home/etiene-niyomugabo123/miniconda3/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim) (2.3.0)
# Downloading gensim-4.4.0-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 1.5 MB/s eta 0:00:00m eta 0:00:010:01:02
# Downloading smart_open-8.0.1-py3-none-any.whl (73 kB)
# Installing collected packages: smart_open, gensim
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gensim]━━━━ 1/2 [gensim]
# Successfully installed gensim-4.4.0 smart_open-8.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-levenshtein
# Out:
# Collecting python-levenshtein
#   Downloading python_levenshtein-0.27.5-py3-none-any.whl.metadata (3.9 kB)
# Collecting Levenshtein==0.27.5 (from python-levenshtein)
#   Downloading levenshtein-0.27.5-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.5->python-levenshtein)
#   Downloading rapidfuzz-3.14.6-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.5-py3-none-any.whl (9.5 kB)
# Downloading levenshtein-0.27.5-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (157 kB)
# Downloading rapidfuzz-3.14.6-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 820.6 kB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: rapidfuzz, Levenshtein, python-levenshtein
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [python-levenshtein]2m1/3 [Levenshtein]
# Successfully installed Levenshtein-0.27.5 python-levenshtein-0.27.5 rapidfuzz-3.14.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim
import pandas as pd

# %%
df = pd.read_json('./reviews_Cell_Phones_and_Accessories_5/Cell_Phones_and_Accessories_5.json', lines=True)

# %%
df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
# 2  These are awesome and make my phone look so st...        5
# 3  Item arrived in great time and was in perfect ...        4
# 4  awesome! stays on, and looks great. can be use...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# 2                             LOVE LOVE LOVE      1403740800  06 26, 2014
# 3                                      Cute!      1382313600  10 21, 2013
# 4  leopard home button sticker for iphone 4s      1359849600   02 3, 2013

# %%
df.reviewText[1]
# Out:
# 'These stickers work like the review says they do. They stick on great and they stay on the phone. They are super stylish and I can share them with my sister. :)'
